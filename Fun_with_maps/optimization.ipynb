# %%
import osm2rail as orl
subarea_name = 'IHB Blue Island Yard'
download_dir = './osmfile'
osm_file=orl.download_osm_data_from_overpass(subarea_names=subarea_name,download_dir = download_dir,ret_download_path=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# The box of IHB_Blue_Island_Yard is ['41.6372039', '41.6423620', '-87.6599743', '-87.6294597']
#   download progress：0.83 MB(0.83 MB)  "\osmfile"...
# Done.

# %%
net=orl.get_network_from_file(filename='osm_krankfurt/map.osm',POIs=True,target_elements=['Frankfurt']) 
orl.show_network(net)
